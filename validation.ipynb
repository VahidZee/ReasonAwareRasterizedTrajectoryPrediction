# %%
from raster.lyft.validation import ValidateModel
from l5kit.configs import load_config_data
from raster.lyft import LyftTrainerModule, LyftDataModule
import seaborn as sns
config = load_config_data("config.yaml")
data = LyftDataModule('/Users/vahidzee/Desktop/data/lyft_data/', config)
data.setup()

model = LyftTrainerModule(config) 
validator = ValidateModel(model, data.rasterizer, visualize=True)
res = validator.validate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-74d8c4d8df70> in <module>
#       5 config = load_config_data("config.yaml")
#       6 data = LyftDataModule('/Users/vahidzee/Desktop/data/lyft_data/', config)
# ----> 7 data.setup()
#       8
#       9 model = LyftTrainerModule(config)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pytorch_lightning/core/datamodule.py in wrapped_fn(*args, **kwargs)
#      82             obj._has_prepared_data = True
#      83
# ---> 84         return fn(*args, **kwargs)
#      85
#      86     return wrapped_fn
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pytorch_lightning/core/datamodule.py in wrapped_fn(*args, **kwargs)
#      82             obj._has_prepared_data = True
#      83
# ---> 84         return fn(*args, **kwargs)
#      85
#      86     return wrapped_fn
#
# ~/Desktop/EPFL/raster/raster-git/raster/lyft/data/module.py in setup(self, stage)
#      27     def setup(self, stage=None):
#      28         self.data_manager = LocalDataManager(self.root_folder)
# ---> 29         self.rasterizer = build_rasterizer(self.config, self.data_manager)
#      30         if stage == 'fit' or stage is None:
#      31             print(self.config['train_dataloader'].get('splits',
#
# ~/opt/miniconda3/lib/python3.7/site-packages/l5kit/rasterization/rasterizer_builder.py in build_rasterizer(cfg, data_manager)
#     163                 history_num_frames,
#     164                 semantic_map_filepath,
# --> 165                 world_to_ecef,
#     166             )
#     167         else:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/l5kit/rasterization/sem_box_rasterizer.py in __init__(self, raster_size, pixel_size, ego_center, filter_agents_threshold, history_num_frames, semantic_map_path, world_to_ecef)
#      30
#      31         self.box_rast = BoxRasterizer(raster_size, pixel_size, ego_center, filter_agents_threshold, history_num_frames)
# ---> 32         self.sat_rast = SemanticRasterizer(raster_size, pixel_size, ego_center, semantic_map_path, world_to_ecef)
#      33
#      34     def rasterize(
#
# ~/opt/miniconda3/lib/python3.7/site-packages/l5kit/rasterization/semantic_rasterizer.py in __init__(self, raster_size, pixel_size, ego_center, semantic_map_path, world_to_ecef)
#      74         self.proto_API = MapAPI(semantic_map_path, world_to_ecef)
#      75
# ---> 76         self.bounds_info = self.get_bounds()
#      77
#      78     # TODO is this the right place for this function?
#
# ~/opt/miniconda3/lib/python3.7/site-packages/l5kit/rasterization/semantic_rasterizer.py in get_bounds(self)
#      95
#      96             if self.proto_API.is_lane(element):
# ---> 97                 lane = self.proto_API.get_lane_coords(element_id)
#      98                 x_min = min(np.min(lane["xyz_left"][:, 0]), np.min(lane["xyz_right"][:, 0]))
#      99                 y_min = min(np.min(lane["xyz_left"][:, 1]), np.min(lane["xyz_right"][:, 1]))
#
# ~/opt/miniconda3/lib/python3.7/site-packages/l5kit/data/map_api.py in get_lane_coords(self, element_id)
#     124             left_boundary.vertex_deltas_y_cm,
#     125             left_boundary.vertex_deltas_z_cm,
# --> 126             lane.geo_frame,
#     127         )
#     128         xyz_right = self.unpack_deltas_cm(
#
# ~/opt/miniconda3/lib/python3.7/site-packages/l5kit/data/map_api.py in unpack_deltas_cm(self, dx, dy, dz, frame)
#      84         frame_lat, frame_lng = self._undo_e7(frame.origin.lat_e7), self._undo_e7(frame.origin.lng_e7)
#      85         xyz = np.stack(pm.enu2ecef(x, y, z, frame_lat, frame_lng, 0), axis=-1)
# ---> 86         xyz = transform_points(xyz, self.ecef_to_world)
#      87         return xyz
#      88
#
# ~/opt/miniconda3/lib/python3.7/site-packages/l5kit/geometry/transform.py in transform_points(points, transf_matrix)
#     113     """
#     114     # TODO: Surely we can do this without transposing.
# --> 115     return transform_points_transposed(points.transpose(1, 0), transf_matrix).transpose(1, 0)
#     116
#     117
#
# ~/opt/miniconda3/lib/python3.7/site-packages/l5kit/geometry/transform.py in transform_points_transposed(points, transf_matrix)
#     131         raise ValueError("Points input should be (2, N), (3,N) or (4,N) shape, received {}".format(points.shape))
#     132
# --> 133     return transf_matrix.dot(np.vstack((points[:num_dims, :], np.ones(points.shape[1]))))[:num_dims, :]
#     134
#     135
#
# ~/opt/miniconda3/lib/python3.7/site-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     206     """
#     207     a = empty(shape, dtype, order)
# --> 208     multiarray.copyto(a, 1, casting='unsafe')
#     209     return a
#     210
#
# <__array_function__ internals> in copyto(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
from raster.lyft.data.preprocess import DataSplitter

splitter = DataSplitter(data.train_data, prog=True, autosave=True)
splitter.split()

# %%
axes = splitter.plot_stats(kind='violin', dodge=True, split=True)
